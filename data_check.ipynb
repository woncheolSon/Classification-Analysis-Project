# %%
import pickle

# %% [markdown]
# # Version 1

# %% [markdown]
# #### - train.csv

# %%
# %%time
train_v1 = pickle.load(open("./data/final_train_Ver1.pkl", "rb"))
print("test data shape: "+str(train.shape))
# Out:
# test data shape: (95674, 5494)
# CPU times: user 263 ms, sys: 651 ms, total: 914 ms
# Wall time: 1.41 s

# %% [markdown]
# #### - test.csv

# %%
# %%time
test_v1 = pickle.load(open("./data/final_test_Ver1.pkl", "rb"))
print("test data shape: "+str(test.shape))
# Out:
# test data shape: (95674, 5493)
# CPU times: user 192 ms, sys: 494 ms, total: 687 ms
# Wall time: 700 ms

# %%
train_v1.tail()
# Out:
#              TripType  Sunday  Saturday  Friday  Monday  Tuesday  Wednesday  \
# VisitNumber
# 191343             25       7         0       0       0        0          0
# 191344             22       5         0       0       0        0          0
# 191345             39      13         0       0       0        0          0
# 191346             39      17         0       0       0        0          0
# 191347              8       2         0       0       0        0          0
#
#              Thursday  SC__-12  SC__-10     ...      FLN_9817.0  FLN_9818.0  \
# VisitNumber                                 ...
# 191343              0        0        0     ...               0           0
# 191344              0        0        0     ...               0           0
# 191345              0        0        0     ...               0           0
# 191346              0        0        0     ...               0           0
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Version 2

# %% [markdown]
# #### - train.csv

# %%
# %%time
train_v2 = pd.read_csv("./data/final_train_Ver2.csv")
print("test data shape: "+str(train.shape))
# Out:
# test data shape: (95674, 5494)
# CPU times: user 4min 37s, sys: 38 s, total: 5min 15s
# Wall time: 5min 22s

# %% [markdown]
# #### - test.csv

# %%
# %%time
test_v2 = pd.read_csv("./data/final_test_Ver2.csv")
print("test data shape: "+str(train.shape))
# Out:
# test data shape: (95674, 5494)
# CPU times: user 4min 24s, sys: 28.7 s, total: 4min 53s
# Wall time: 4min 56s

# %%
train_v2.tail()
# Out:
#        VisitNumber  TripType  Sunday  Saturday  Friday  Monday  Tuesday  \
# 95669       191343        25       7         0       0       0        0
# 95670       191344        22       5         0       0       0        0
# 95671       191345        39      13         0       0       0        0
# 95672       191346        39      17         0       0       0        0
# 95673       191347         8       2         0       0       0        0
#
#        Wednesday  Thursday  Upc_3082.0     ...      FLN_9817.0  FLN_9818.0  \
# 95669          0         0         0.0     ...               0           0
# 95670          0         0         0.0     ...               0           0
# 95671          0         0         0.0     ...               0           0
# 95672          0         0         0.0     ...               0           0
# 95673          0         0         0.0     ...               0           0
#
#        FLN_9865.0  FLN_9894.0  FLN_9895.0  FLN_9916.0  FLN_9940.0  FLN_9945.0  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Version 3

# %% [markdown]
# #### - train.csv

# %%
# %%time
train_v3 = pickle.load(open("./data/final_train_Ver3.pkl", "rb"))
print("test data shape: "+str(train.shape))
# Out:
# test data shape: (95674, 5494)
# CPU times: user 275 ms, sys: 683 ms, total: 958 ms
# Wall time: 971 ms

# %% [markdown]
# #### - test.csv

# %%
# %%time
test_v3 = pickle.load(open("./data/final_test_Ver3.pkl", "rb"))
print("test data shape: "+str(test.shape))
# Out:
# test data shape: (95674, 5493)
# CPU times: user 268 ms, sys: 711 ms, total: 979 ms
# Wall time: 998 ms

# %%
train_v3.tail()
# Out:
#              TripType  Min  Max    Mean  Max - Min  FLN_count  Upc_count  \
# VisitNumber
# 191343             25    7   42  21.000         35         35         49
# 191344             22    5   20  12.500         15         15         25
# 191345             39   13   65  27.625         52        156        169
# 191346             39   17   85  36.125         68        272        289
# 191347              8    2    2   2.000          0          4          4
#
#              DD_count  Sum  FLN_DD_Ratio     ...      FLN_9817.0  FLN_9818.0  \
# VisitNumber                                  ...
# 191343             21   63     11.666667     ...               0           0
# 191344             10   25      7.500000     ...               0           0
# 191345            104  221     19.500000     ...               0           0
# 191346            136  289     34.000000     ...               0           0
# 191347              4    4      2.000000     ...               0           0
#
# ...

# %% [markdown]
# ---
